# %% [markdown]
# # TP - Generación de Prompts Coder House
# Analysis of Factors Associated with Positive COVID-19 Results from IATos in the City of Buenos Aires

# %% [markdown]
# ## Summary
# This project aims to analyze the demographic and temporal factors associated with positive COVID-19 results in the City of Buenos Aires using a dataset of IAtos cases related to COVID-19. Variables such as gender, age range, and test date will be explored to identify possible correlations with positive COVID-19 results. This analysis will provide valuable information to better understand the distribution and dynamics of the disease in the city at that time. Although it represents a temporary "snapshot," the applied analytics are replicable for each year/sample considered.

# %% [markdown]
# ## Indexerencesencias

# %% [raw]
# Introduction.
# Objectives.
# Methodology.
# Tools and Technologies.
# Implementation.
# Results.
# Conclusions.
# References.

# %% [markdown]
# ### 1 Introduction
# Problem Statement The COVID-19 pandemic has had a significant impact on the City of Buenos Aires (and the world), and understanding the factors associated with positive COVID-19 results is crucial to inform prevention and control strategies for the disease.
# Solution Proposal Development A public IAtos dataset related to COVID-19 will be used to analyze demographic and temporal factors. Artificial intelligence techniques will be employed to generate textual and visual descriptions of the data.
# Justification of Project Viability: The project is technically feasible using tools such as Smart Dataframe for data analysis and Fast Prompting with the OpenAI API for generating textual and visual descriptions.

# %% [markdown]
# ### 2 Objectives
#
# Analyze demographic factors (gender, age range) associated with positive COVID-19 results.
# Investigate any temporal trends in the prevalence of positive COVID-19 results over time.

# %% [markdown]
# ### 3 Methodology
#
# Data Collection and Preprocessing: The "tos-covid-19.csv" dataset published on BA DATA will be used. Rows with null values will be removed, and any other necessary preprocessing will be performed.
#
# Exploratory Data Analysis: A descriptive analysis of relevant variables, including gender and age range distribution, as well as the temporal evolution of test results, will be conducted.
#
# Statistical Modeling: Statistical techniques will be used to investigate the relationships between demographic and temporal variables and COVID-19 results.

# %% [markdown]
# ### 4 Tools and Technologies
#
# Fast Prompting techniques with the OpenAI API, especially the GPT-3.5 API for generating textual descriptions, and the NIghtCafe API for converting those descriptions into images will be used. The use of these tools is justified due to their ability to generate text and images based on textual descriptions, which is suitable for data analysis and visualization in this project.

# %% [markdown]
# ### 5 Implementation

# %% [markdown]
# 5.1. Import openAI dependences (load with conda install openai)

# %%
from pandasai import SmartDataframe
import pandas as pd
from pandasai.llm import OpenAI
import warnings

# %% [markdown]
# 5.2. Use the API Key from openAI page

# %%
#Add our API Key copied from openAI page
llm = OpenAI(api_token="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")

# %% [markdown]
# 5.3. Set other settings of envoirement

# %%
#Source to download the DataFrame: https://github.com/gcba/IATos/blob/main/dataset/tos-covid-19.csv
#csv_file = r""C:\Users\Admin\Desktop\CODER\tos-covid-19.csv" 
csv_file = "tos-covid-19.csv"

# Read the file as a DataFrame
df_from_csv_file = pd.read_csv(csv_file)

# %%
# DataFrame
df_from_csv_file
# Out:
#       id_unico genero rango_etario fecha_hisopado resultado_hisopado subset
# 0            1      F            2     2020-09-01         Detectable  train
# 1            2      M            3     2020-08-25      No Detectable  train
# 2            3      F            2     2020-08-27         Detectable  train
# 3            4      F            3     2020-08-28      No Detectable  train
# 4            5      F            3     2020-08-28      No Detectable  train
# ...        ...    ...          ...            ...                ...    ...
# 2766      7634      F            -              -         Detectable   test
# 2767      7639      F            -              -         Detectable   test
# 2768      7680      F            -              -         Detectable   test
# 2769      7726      F            -              -         Detectable   test
# 2770      7752      M            -              -         Detectable   test
#
# [2771 rows x 6 columns]

# %% [markdown]
# 5.4 Transform the DataFrame to an Artificial Intelligence Dataframe

# %%
# Make the DataFrame to an Artificial Intelligence Dataframe
ai_df = SmartDataframe(df_from_csv_file, config={"llm": llm})

# %% [markdown]
# 5.4.1 Retrieve the results of the query as a natural language (as an Human)

# %%
#Chat = Receive as a block of answers (Dataframe or text)
ai_df.chat("Return the detectable cases")
# Out:
#       id_unico genero rango_etario fecha_hisopado resultado_hisopado subset
# 0            1      F            2     2020-09-01         Detectable  train
# 2            3      F            2     2020-08-27         Detectable  train
# 5            6      M            2     2020-08-28         Detectable  train
# 6            7      F            2     2020-08-28         Detectable  train
# 7            9      M            2     2020-09-03         Detectable  train
# ...        ...    ...          ...            ...                ...    ...
# 2766      7634      F            -              -         Detectable   test
# 2767      7639      F            -              -         Detectable   test
# 2768      7680      F            -              -         Detectable   test
# 2769      7726      F            -              -         Detectable   test
# 2770      7752      M            -              -         Detectable   test
#
# [1223 rows x 6 columns]

# %% [markdown]
# 5.6 Make an application that answer questions about the Data Base (DF)

# %%
##Chat = Receive as a block of answers (Dataframe or text)
while True:
    user_input = input("What is your question about the database? (If you don't have one, press 'q' to finish the program): ")
    if user_input.lower() == 'q':
        break
    else:
        response = ai_df.chat(user_input)
        print(response)
# Out:
# What is your question about the database? (If you don't have one, press 'q' to finish the program):  "Could you please provide the distribution of gender among COVID-19 cases in the dataset?"
#   Gender  Count
# 0      F   1395
# 1      M   1205
# 2      -     16
# What is your question about the database? (If you don't have one, press 'q' to finish the program):  "Can you show me the distribution of age ranges among COVID-19 cases?"
# C:/Users/Admin/Desktop/CODER/exports/charts/temp_chart.png
# What is your question about the database? (If you don't have one, press 'q' to finish the program):  "I'd like to see how the number of COVID-19 test results has evolved over time. Can you show me the temporal evolution of test results?"
# C:/Users/Admin/Desktop/CODER/exports/charts/temp_chart.png
# What is your question about the database? (If you don't have one, press 'q' to finish the program):  q

# %% [markdown]
# ### 6 Results
# The implementation of the project provides visual results on the gender distribution and temporal evolution of test results in the City of Buenos Aires. These results allow for the visualization of patterns and trends in COVID-19-related data, which may help better understand the dynamics of the disease in the city.

# %% [markdown]
# ### 7 Conclusions
# The exploratory data analysis provides valuable information on the gender distribution and temporal evolution of test results in the City of Buenos Aires. The project objectives have been achieved by analyzing and visualizing the factors associated with positive COVID-19 results. The use of tools such as Fast Prompting with the OpenAI API has facilitated the generation of textual descriptions and visualization of results.

# %% [markdown]
# ### 8.References
#
# Dataset "tos-covid-19.csv": https://github.com/gcba/IATos/blob/main/dataset/tos-covid-19.csv
